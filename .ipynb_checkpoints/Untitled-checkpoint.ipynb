# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime
# %matplotlib inline

# %%
df = pd.concat(pd.read_excel('phone-data.xlsx', sheet_name= None), ignore_index=True)

# %%
df['date'] = pd.to_datetime(df['date'],format="%Y/%m/%d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f959375890f6> in <module>
# ----> 1 df['date'] = pd.to_datetime(df['date'],format="%Y/%m/%d")
#
# ...

# %%
df.dtypes

# %%
df.head(95)

# %%
phone_dict = df['Anonymous Bank Call-Center Data']

# %%
phone_dict.head(95)

# %%
phone_dict=phone_dict.drop((94,444541),inplace=True)

# %%
phone_dict

# %%
del df['Anonymous Bank Call-Center Data']

# %%
df = df.drop(range(0,93))

# %%
df = df.drop((93))

# %%
df.reset_index()
# Out:
#          index vru+line  call_id  customer_id priority type  \
# 0           94   AA0101  33116.0    9664491.0        2   PS
# 1           95   AA0101  33117.0          0.0        0   PS
# 2           96   AA0101  33118.0   27997683.0        2   PS
# 3           97   AA0101  33119.0          0.0        0   PS
# 4           98   AA0101  33120.0          0.0        0   PS
# ...        ...      ...      ...          ...      ...  ...
# 444443  444537   AA0216  17211.0          0.0        0   IN
# 444444  444538   AA0216  17212.0          0.0        0   IN
# 444445  444539   AA0216  17213.0          0.0        0   IN
# 444446  444540   AA0216  17214.0          0.0        0   IN
# 444447  444541   AA0216  17215.0          0.0        0   IN
#
#                        date vru_entry  vru_exit vru_time   q_start    q_exit  \
# 0       1999-01-01 00:00:00  00:00:31  00:00:36        5  00:00:36  00:03:09
# 1       1999-01-01 00:00:00  00:34:12  00:34:23       11  00:00:00  00:00:00
# ...

# %%
df['date'].sample(100)
# Out:
# 260086             08/09/1999
# 6577               01/04/1999
# 165961             05/06/1999
# 276693             08/10/1999
# 424528    1999-12-10 00:00:00
#                  ...
# 400405             11/11/1999
# 235046             07/21/1999
# 187362             06/01/1999
# 26506              01/03/1999
# 441801    1999-12-20 00:00:00
# Name: date, Length: 100, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'],format="%Y/%m/%d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-f959375890f6> in <module>
# ----> 1 df['date'] = pd.to_datetime(df['date'],format="%Y/%m/%d")
#
# ...

# %%
df['date'] = df.date.apply(
    lambda x: pd.to_datetime(x).strftime('%m/%d/%Y')[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-67-7a1ef35d0739> in <module>
# ----> 1 df['date'] = df.date.apply(
#       2     lambda x: pd.to_datetime(x).strftime('%m/%d/%Y')[0])
#
# ...

# %%
df['date']

# %%
pd.to_datetime(date_col_to_force, errors = 'coerce')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-59fc59781a7f> in <module>
# ----> 1 pd.to_datetime(date_col_to_force, errors = 'coerce')
#
# NameError: name 'date_col_to_force' is not defined

# %%
df['date'].apply(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y %H:%M:%S') if type(x)==str else np.NaN)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-8be607980095> in <module>
# ----> 1 df['date'].apply(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y %H:%M:%S') if type(x)==str else np.NaN)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-70-8be607980095> in <lambda>(x)
# ----> 1 df['date'].apply(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y %H:%M:%S') if type(x)==str else np.NaN)
#
# ...

# %%
df.sample(200)
# Out:
#        vru+line  call_id  customer_id priority type                 date  \
# 265203   AA0201  43426.0   25213869.0        1   PS  1999-08-02 00:00:00
# 270749   AA0203  46323.0          0.0        0   NW  1999-08-15 00:00:00
# 137304   AA0102  34916.0          0.0        0   NW  1999-05-04 00:00:00
# 81335    AA0113   6740.0   55568687.0        2   PS  1999-03-17 00:00:00
# 328266   AA0103  38176.0          0.0        0   NW  1999-10-21 00:00:00
# ...         ...      ...          ...      ...  ...                  ...
# 303292   AA0110  39714.0   57252942.0        2   PS  1999-09-13 00:00:00
# 212656   AA0215  21276.0   27922665.0        2   PS  1999-06-16 00:00:00
# 324029   AA0215  25792.0          0.0        0   PS  1999-09-24 00:00:00
# 380583   AA0202  51415.0          0.0        0   PS  1999-11-10 00:00:00
# 169281   AA0213  19154.0   54042171.0        2   NE  1999-05-02 00:00:00
#
#        vru_entry  vru_exit vru_time   q_start    q_exit q_time outcome  \
# ...
